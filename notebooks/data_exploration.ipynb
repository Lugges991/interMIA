# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/mnt/DATA/datasets/ABIDEII/ABIDEII_all_combined_drop_columns.csv")

# %%
df
# Out:
#               SITE_ID  SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX  \
# 0       ABIDEII-BNI_1   29006         1          48.0    1
# 1       ABIDEII-BNI_1   29007         1          41.0    1
# 2       ABIDEII-BNI_1   29008         1          59.0    1
# 3       ABIDEII-BNI_1   29009         1          57.0    1
# 4       ABIDEII-BNI_1   29010         1          45.0    1
# ...               ...     ...       ...           ...  ...
# 1185  ABIDEII-U_MIA_1   30252         2          11.3    1
# 1186  ABIDEII-U_MIA_1   30253         2           7.6    2
# 1187  ABIDEII-U_MIA_1   30254         1           8.3    2
# 1188  ABIDEII-U_MIA_1   30255         2           7.1    1
# 1189  ABIDEII-U_MIA_1   30256         2           8.3    1
#
#       HANDEDNESS_CATEGORY    FIQ    VIQ    PIQ
# 0                     1.0  131.0    NaN    NaN
# 1                     1.0  110.0    NaN    NaN
# 2                     1.0  117.0    NaN    NaN
# 3                     1.0  114.0    NaN    NaN
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("grayscale")

# %%
one = np.count_nonzero(df.DX_GROUP.values == 1)
two = np.count_nonzero(df.DX_GROUP.values == 2)

# %%
plt.bar([1, 2], [one, two], tick_label=["ASD", "TC"])
plt.show()

# %%
sites = np.unique(df.SITE_ID.values)

site_1 = []
site_2 = []

for site in sites:
    site_1.append(np.count_nonzero(df[df.SITE_ID==site].DX_GROUP.values == 1))
    site_2.append(np.count_nonzero(df[df.SITE_ID==site].DX_GROUP.values == 2))

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i])

# %%
xs = np.arange(len(sites))

plt.rcParams["figure.figsize"] = (15,6)

fig, ax = plt.subplots()
width = .4

rects1 = ax.bar(xs - 0.2, site_1, width=width, label="ASD")
rects2 = ax.bar(xs + 0.2, site_2, width=width, label="TC")

ax.set_ylabel("Subjects")
ax.set_title("Number of ASD and TC Subjects per Site")
ax.set_xticks(xs, sites, rotation="vertical")
ax.legend()

ax.bar_label(rects1, padding=3, rotation="vertical")
ax.bar_label(rects2, padding=3, rotation="vertical")
plt.savefig("asd_tc_distribution.png")
plt.show()

# %%
df_GU = df[df.SITE_ID=="ABIDEII-GU_1"]

# %%
df_GU.columns
# Out:
# Index(['SITE_ID', 'SUB_ID', 'DX_GROUP', 'AGE_AT_SCAN ', 'SEX',
#        'HANDEDNESS_CATEGORY', 'FIQ', 'VIQ', 'PIQ'],
#       dtype='object')

# %%
df.head()
# Out:
#          SITE_ID  SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX  HANDEDNESS_CATEGORY  \
# 0  ABIDEII-BNI_1   29006         1          48.0    1                  1.0
# 1  ABIDEII-BNI_1   29007         1          41.0    1                  1.0
# 2  ABIDEII-BNI_1   29008         1          59.0    1                  1.0
# 3  ABIDEII-BNI_1   29009         1          57.0    1                  1.0
# 4  ABIDEII-BNI_1   29010         1          45.0    1                  1.0
#
#      FIQ  VIQ  PIQ
# 0  131.0  NaN  NaN
# 1  110.0  NaN  NaN
# 2  117.0  NaN  NaN
# 3  114.0  NaN  NaN
# 4  109.0  NaN  NaN

# %%
df_GU["AGE_AT_SCAN "].describe()
# Out:
# count    106.000000
# mean      10.663940
# std        1.628584
# min        8.063014
# 25%        9.186986
# 50%       10.606849
# 75%       11.978082
# max       13.906849
# Name: AGE_AT_SCAN , dtype: float64

# %%
df
# Out:
#               SITE_ID  SUB_ID  DX_GROUP  AGE_AT_SCAN   SEX  \
# 0       ABIDEII-BNI_1   29006         1          48.0    1
# 1       ABIDEII-BNI_1   29007         1          41.0    1
# 2       ABIDEII-BNI_1   29008         1          59.0    1
# 3       ABIDEII-BNI_1   29009         1          57.0    1
# 4       ABIDEII-BNI_1   29010         1          45.0    1
# ...               ...     ...       ...           ...  ...
# 1185  ABIDEII-U_MIA_1   30252         2          11.3    1
# 1186  ABIDEII-U_MIA_1   30253         2           7.6    2
# 1187  ABIDEII-U_MIA_1   30254         1           8.3    2
# 1188  ABIDEII-U_MIA_1   30255         2           7.1    1
# 1189  ABIDEII-U_MIA_1   30256         2           8.3    1
#
#       HANDEDNESS_CATEGORY    FIQ    VIQ    PIQ
# 0                     1.0  131.0    NaN    NaN
# 1                     1.0  110.0    NaN    NaN
# 2                     1.0  117.0    NaN    NaN
# 3                     1.0  114.0    NaN    NaN
# ...
